# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Data structure:[restaurant_id, 2021, 2022, 2023, 2024]
sales_data=np.array([
    [1,120,145,167,189],
    [1,12,145,17,1899],
    [16,120,45,167,19]
])

# %%
#total sales per year
print(np.sum(sales_data,axis=0))
yearly_total=np.sum(sales_data[:,1:], axis=0)
print(yearly_total)

#[:,1:] -> : start from 0th row

# 1: -> start from 1th column till end

# axis=0 vertical adding -> column wise adding
# Out:
# [  18  252  335  351 2107]
# [ 252  335  351 2107]

# %%
#For finding:
#  minimum and maximum sales-> min max
# for mean -> mean
# Cumulative sum= cumsum

# %% [markdown]
# ## Matplotlib idea

# %%
cumsum=np.cumsum(sales_data[:,1:],axis=1)
print(cumsum)

plt.figure(figsize=(10,6))
plt.plot(np.mean(cumsum,axis=0))
plt.title("Average cumulative sales")
plt.xlabel("Years")
plt.ylabel("Sales")
plt.grid(True)
plt.show()
# Out:
# [[ 120  265  432  621]
#  [  12  157  174 2073]
#  [ 120  165  332  351]]

# %% [markdown]
# ## Vector Operations

# %%
vector1=np.array([1,2,3])
vector2=np.array([4,5,6])

print("Dot product", np.dot(vector1,vector2))

angle= np.arccos(np.dot(vector1,vector2)/(np.linalg.norm(vector1)*np.linalg.norm(vector2)))
print(angle)
# Out:
# Dot product 32
# 0.2257261285527342
